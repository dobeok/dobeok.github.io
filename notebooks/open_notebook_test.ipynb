# %% [markdown]
# <a href="https://colab.research.google.com/github/dobeok/dobeok.github.io/blob/master/notebooks/open_notebook_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x = np.random.rand(10)

# %%
x
# Out:
# array([0.58172008, 0.9153178 , 0.40790028, 0.90467583, 0.86676846,
#        0.87253039, 0.84077339, 0.14979603, 0.55399536, 0.2147119 ])

# %%
y = np.random.rand(10)

# %%
x+y
# Out:
# array([0.66860022, 0.9469102 , 0.9726445 , 1.67339521, 1.44661267,
#        1.40661564, 1.56314335, 0.60384172, 1.07109587, 0.29844678])
